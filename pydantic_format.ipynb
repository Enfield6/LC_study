# %%
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain.agents import create_agent
import os
from dotenv import load_dotenv
from pydantic import BaseModel
from langchain_tavily import TavilySearch

load_dotenv(override= True, dotenv_path= ".env")
api_key = os.getenv("DEEPSEEK_API_KEY")
tavily_api_key = os.getenv("TAVILY_API_KEY")

model = init_chat_model(api_key = api_key,
                        model = "deepseek-v4-flash",
                        base_url = "https://api.deepseek.com",
                        model_provider= "deepseek",
                        )

model.invoke("Hello！")
# Out:
# AIMessage(content='Hello！👋 很高兴见到你！我是DeepSeek，一个乐于助人的AI助手。\n\n有什么我可以帮你的吗？无论是想聊聊天、解答问题、写点文字，还是需要其他帮助，尽管告诉我！😊\n\n比如你可以：\n- 说说你感兴趣的话题\n- 问一个问题\n- 让我帮你写点东西\n- 或者只是随便聊聊也行！\n\n今天有什么想交流的吗？', additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户发来一个简单的问候“Hello！”。这是一个非常基础的社交开场，没有提出任何具体问题或指令。深层需求可能是测试我是否能回应，或者只是开启对话。我需要给出一个友好、热情且开放的回复，确认收到问候，并主动提供帮助方向，引导用户提出后续问题。想到了用“Hello！👋”开头，保持亲切感，然后用“很高兴见到你”表达积极态度。接着说明自己的身份和角色，最后用几个开放性的示例问题来邀请用户进一步交流，比如问名字、聊爱好、需要帮助的具体领域。这样既回应了问候，又为对话的延续创造了顺畅的入口。'}, response_metadata={'token_usage': {'completion_tokens': 225, 'prompt_tokens': 6, 'total_tokens': 231, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 137, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '3e770fd3-7c0b-4d43-9a52-030d8ee85346', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4a0c-4887-7ec0-b063-e55759a5cf91-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 225, 'total_tokens': 231, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 137}})
